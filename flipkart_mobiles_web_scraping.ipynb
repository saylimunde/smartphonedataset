# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
product_name = []
prices = []
description = []
ratings = []

for i in range(2,12):
    url = "https://www.flipkart.com/mobiles/pr?sid=tyy%2C4io&param=19873&ctx=eyJjYXJkQ29udGV4dCI6eyJhdHRyaWJ1dGVzIjp7InRpdGxlIjp7Im11bHRpVmFsdWVkQXR0cmlidXRlIjp7ImtleSI6InRpdGxlIiwiaW5mZXJlbmNlVHlwZSI6IlRJVExFIiwidmFsdWVzIjpbIk1vdG9yb2xhIHNtYXJ0cGhvbmVzIl0sInZhbHVlVHlwZSI6Ik1VTFRJX1ZBTFVFRCJ9fX19fQ%3D%3D&bu=MOBILE&wid=42.productCard.PMU_V2_39&page="+str(i)
        
    # r = requests.get(url)
    # print(r)
        
    soup = BeautifulSoup(r.text,'lxml')
    box = soup.find('div',class_ = 'DOjaWF gdgoEp')
    # print(soup)
    
    names = box.find_all('div',class_ = 'KzDlHZ')
    print(names)
    
    for i in names:
        product_name.append(i.text)
        
    print(product_name)
    
    price = box.find_all('div',class_ = 'Nx9bqj _4b5DiR')
    
    for i in price:
        prices.append(i.text)
    
    print(prices)
    
    specs = box.find_all('ul',class_ = 'G4BRas')
    
    for i in specs:
        description.append(i.text)

    print(description)
    
    rating = box.find_all('div',class_= 'XQDdHH')
    
    for i in rating:
        ratings.append(i.text)


    print(ratings)
# np = soup.find('a',class_ = '_9QVEpD').get('href')
# cnp = 'https://www.flipkart.com' + np	
        
# print(cnp)
    
    # url = cnp
    
    # r = requests.get(url)
    
    # soup = BeautifulSoup(r.text,'lxml')
# Out:
# [<div class="KzDlHZ">MOTOROLA Edge 60 Fusion 5G (PANTONE Mykonos Blue, 256 GB)</div>, <div class="KzDlHZ">Motorola G85 5G (Olive Green, 128 GB)</div>, <div class="KzDlHZ">Motorola G85 5G (Urban Grey, 128 GB)</div>, <div class="KzDlHZ">Motorola Edge 50 Fusion (Marshmallow Blue, 128 GB)</div>, <div class="KzDlHZ">POCO C75 5G (Enchanted Green, 64 GB)</div>, <div class="KzDlHZ">Motorola G85 5G (Cobalt Blue, 128 GB)</div>, <div class="KzDlHZ">Motorola Edge 50 Fusion (Forest Blue, 256 GB)</div>, <div class="KzDlHZ">Motorola G85 5G (Viva Magenta, 128 GB)</div>, <div class="KzDlHZ">MOTOROLA Edge 60 Fusion 5G (PANTONE Slipstream, 256 GB)</div>, <div class="KzDlHZ">Tecno Pova 6 Neo 5G (Midnight Shadow, 128 GB)</div>, <div class="KzDlHZ">POCO C75 5G (Enchanted Green, 128 GB)</div>, <div class="KzDlHZ">Motorola G85 5G (Olive Green, 256 GB)</div>, <div class="KzDlHZ">Motorola g45 5G (Brilliant Green, 128 GB)</div>, <div class="KzDlHZ">MOTOROLA Edge 60 Fusion 5G (PANTONE Zephyr, 256 GB)</div>, <di
# ...

# %%
df = pd.DataFrame({'model':product_name,
                 'prices':prices,
                 'description':description,
                 'rating':ratings})

# %%
df.to_csv("C:/Users/alank/flipkard_mobiles_under_50000.csv")

# %%
df.head()
# Out:
#                                                model   prices  \
# 0  MOTOROLA Edge 60 Fusion 5G (PANTONE Mykonos Bl...  ₹22,999
# 1              Motorola G85 5G (Olive Green, 128 GB)  ₹16,999
# 2               Motorola G85 5G (Urban Grey, 128 GB)  ₹16,999
# 3  Motorola Edge 50 Fusion (Marshmallow Blue, 128...  ₹18,999
# 4               POCO C75 5G (Enchanted Green, 64 GB)   ₹7,699
#
#                                          description rating
# 0  8 GB RAM | 256 GB ROM | Expandable Upto 1 TB16...    4.5
# 1  8 GB RAM | 128 GB ROM16.94 cm (6.67 inch) Full...    4.4
# 2  8 GB RAM | 128 GB ROM16.94 cm (6.67 inch) Full...    4.4
# 3  8 GB RAM | 128 GB ROM17.02 cm (6.7 inch) Full ...    4.5
# 4  4 GB RAM | 64 GB ROM | Expandable Upto 1 TB17....    4.3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   model        240 non-null    object
#  1   prices       240 non-null    object
#  2   description  240 non-null    object
#  3   rating       240 non-null    object
# dtypes: object(4)
# memory usage: 7.6+ KB
